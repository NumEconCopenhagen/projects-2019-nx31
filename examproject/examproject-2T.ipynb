# %% [markdown]
# ## NX31 Examproject

# %% [markdown]
# ## Packages and extensions

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import scipy as sp
from scipy import optimize
from scipy import interpolate
import sympy as sm
from IPython.display import display
import ipywidgets as widgets

# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
sm.init_printing(use_unicode=True)

# %% [markdown]
# ## Introduction
#
# This examproject is made by our own effort combined with inspiration from Problem sets, Lecture notebooks and earlier project. We have also gotten inspiration from Google/Stackoverflow searches.

# %% [markdown]
# # Human capital accumulation

# %% [markdown]
# Consider a worker living in **two periods**, $t \in \{1,2\}$.
#
# In each period she decides whether to **work ($l_t = 1$) or not ($l_t = 0$)**.
#
# She can *not* borrow or save and thus **consumes all of her income** in each period.

# %% [markdown]
# If she **works** her **consumption** becomes:
#
# $$c_t = w h_t l_t\,\,\text{if}\,\,l_t=1$$
#
# where $w$ is **the wage rate** and $h_t$ is her **human capital**.
#
# If she does **not work** her consumption becomes:
#
# $$c_t = b\,\,\text{if}\,\,l_t=0$$
#
# where $b$ is the **unemployment benefits**.

# %% [markdown]
# Her **utility of consumption** is:
#
# $$ \frac{c_t^{1-\rho}}{1-\rho} $$
#
# Her **disutility of working** is:
#
# $$ \gamma l_t $$

# %% [markdown]
# From period 1 to period 2, she **accumulates human capital** according to:
#
# $$ h_2 = h_1 + l_1 +
# \begin{cases}
# 0 & \text{with prob. }0.5 \\
# \Delta & \text{with prob. }0.5
# \end{cases} \\
# $$
#
# where $\Delta$ is a **stochastic experience gain**.

# %% [markdown]
# In the **second period** the worker thus solves:
#
# $$
# \begin{eqnarray*}
# v_{2}(h_{2}) & = &\max_{l_{2}} \frac{c_2^{1-\rho}}{1-\rho} - \gamma l_2
# \\ & \text{s.t.} & \\
# c_{2}& = & w h_2 l_2 \\
# l_{2}& \in &\{0,1\}
# \\ & \text{ NEW - s.t.} & \\
# c_{2}& = & \begin{cases}
# w h_2 &
# \text{if }l_2 = 1  \\
# b & \text{if }l_2 = 0
# \end{cases} \\
# \end{eqnarray*}
# $$

# %% [markdown]
# In the **first period** the worker thus solves:
#
# $$
# \begin{eqnarray*}
# v_{1}(h_{1}) &=& \max_{l_{1}} \frac{c_1^{1-\rho}}{1-\rho} - \gamma l_1 + \beta\mathbb{E}_{1}\left[v_2(h_2)\right]
# \\ & \text{s.t.} & \\
# c_1 &=& w h_1 l_1 \\
# h_2 &=& h_1 + l_1 + \begin{cases}
# 0 & \text{with prob. }0.5\\
# \Delta & \text{with prob. }0.5
# \end{cases}\\
# l_{1} &\in& \{0,1\}\\
# \end{eqnarray*}
# $$
#
# where $\beta$ is the **discount factor** and $\mathbb{E}_{1}\left[v_2(h_2)\right]$ is the **expected value of living in period two**.

# %% [markdown]
# The **parameters** of the model are:

# %%
rho = 2
beta = 0.96
gamma = 0.1
w = 2
b = 1
Delta = 0.1

# %% [markdown]
# The **relevant levels of human capital** are:

# %%
h_vec = np.linspace(0.1,1.5,100)

# %% [markdown]
# ## **Answer 1**: Human capital accumulation
#
# For the three question concerning Human capital accumulation have taking a lot of inspiration from Problem set 7.4.
#
# Solving the model in period 2 and illustrating labor supply as a function of human capital.
#
# First we set up the functions of the model, both for period one and period two.

# %%
def utility(c,rho):
    return c**(1 - rho)/(1 - rho)

def c(w,h,l,b):
    return w*h*l + b*(1 - l)

def bequest(l,gamma):
    return gamma*l

def v2(w,h2,l2,b,rho,gamma):
    return utility(c(w,h2,l2,b),rho) - bequest(l2,gamma)

def v1(h1,l1,v2_interp,Delta,w,b,rho,gamma,beta):
    
    # a. v2 value, if no accumulation of humancapital
    h2_No = h1 + l1 + 0
    v2_No = v2_interp([h2_No])[0]
    
    # b. v2 value, if accumulation of human capital
    h2_Yes = h1 + l1 + Delta
    v2_Yes = v2_interp([h2_Yes])[0]
    
    # c. expected v2 value
    v2 = 0.5*v2_No + 0.5*v2_Yes
    
    # d. total value
    return utility(c(w,h1,l1,b),rho) - bequest(l1,gamma) + beta*v2

# %% [markdown]
# We now ready to solve Question 1.1.

# %% [markdown]
# **Question 1:** Solve the model in period 2 and illustrate the solution (including labor supply as a function of human capital).

# %% [markdown]
# ### Answer 1.1
#
# Next we will define a function to solve the model for period 2.

# %%
def solve_period_2(rho,gamma,Delta):
    
    # Vectors
    l2_vec = np.empty(100)
    v2_vec = np.empty(100)
    
    # Solve for each h2
    for i,h2 in enumerate(h_vec):
        
        # to work or not to work
        if v2(w,h2,1,b,rho,gamma) < v2(w,h2,0,b,rho,gamma):
            l2_vec[i] = 0
        else:
            l2_vec[i] = 1
        
        v2_vec[i] = v2(w,h2,l2_vec[i],b,rho,gamma)
        
    return l2_vec, v2_vec

# %% [markdown]
# Using our vectors for labor supply ($l_2$) and utility ($v_2$) for each value of human capital ($h_2$) in the given vector h_vec, we will solve the model for period 2. We will also illustrate this below.

# %%
# Symbols
w = sm.symbols('w')
h_2 = sm.symbols('h_2')
rho = sm.symbols('rho')
gamma = sm.symbols('gamma')
v21 = sm.symbols('v_{2, l=1}')
v20 = sm.symbols('v_{2, l=0}')
b = sm.symbols('b')

# %%
# Solves for the kink point in human capial i period 2
print(f'Utility when working:')
v_21 = (w*h_2*1)**(1-rho)/(1-rho)-gamma
display(sm.Eq(v21,v_21))
print(f'Utility whn not working:')
v_20 = b**(1-rho)/(1-rho)
display(sm.Eq(v20,v_20))
print(f'The kink in human capital is then where the two utilities are equal, so we set them equal and isolate h_2:')
display(sm.Eq(v_20,v_21))
f = v_21-v_20
fs = sm.solve(f,h_2)
fs
# Out:
# Utility when working:
#                           -ρ + 1
#                     (h₂⋅w)
# (v_{2, l=1}) = -γ + ────────────
#                        -ρ + 1
# Utility whn not working:
#                 -ρ + 1
#                b
# (v_{2, l=0}) = ───────
#                 -ρ + 1
# The kink in human capital is then where the two utilities are equal, so we set them equal and isolate h_2:
#  -ρ + 1              -ρ + 1
# b              (h₂⋅w)
# ─────── = -γ + ────────────
#  -ρ + 1           -ρ + 1
# ⎡                    -1  ⎤
# ⎢                   ─────⎥
# ⎢                   ρ - 1⎥
# ⎢⎛ -ρ + 1          ⎞     ⎥
# ⎢⎝b       - γ⋅ρ + γ⎠     ⎥
# ⎢────────────────────────⎥
# ⎣           w            ⎦

# %%
rho = 2
beta = 0.96
gamma = 0.1
w = 2
b = 1
h2 = (b**(-rho + 1) - gamma*rho + gamma)**(-1/(rho - 1))/w
print(f'{h2:.4f}')
# Out:
# 0.5556

# %%
# Solving
l2_vec,v2_vec = solve_period_2(rho,gamma,Delta)

# Figure
fig = plt.figure(figsize=(16,6))
ax = fig.add_subplot(1,2,1)
ax1 = fig.add_subplot(1,2,2)
ax.plot(h_vec,l2_vec)
ax1.plot(h_vec,v2_vec)

# Labels
font = {'family':'serif','color':'darkblue','weight':'normal','size': 16,}
ax.set_xlabel('Human Capital ($h_2$)', fontdict=font)
ax.set_ylabel('Labor supply ($l_2$)', fontdict=font)
ax.set_title('Labor supply as a function of human capital in period 2', fontdict=font)
ax.grid()
ax.plot(h2,0.5,marker='o')
ax1.set_xlabel('Human Capital ($h_2$)', fontdict=font)
ax1.set_ylabel('Utility ($v_2$)', fontdict=font)
ax1.set_title('Utility as a function of human capital in period 2', fontdict=font)
ax1.grid()
plt.tight_layout()

# %% [markdown]
# From the figures above, we see that with lower human capital she will tend to not work in period 2. The breakeven between working and not working is 0.5556, marked with a orange dot on the left plot. Thus she will choose to work if h>0.5556. This value is calculated above.
#
# This can also be seen by the kink in the graph. The figure to the left shows at what level of human capital, she will begin to work, whereas the figure on the right shows her total utility development for values in human capital.

# %% [markdown]
# **Question 2:** Solve the model in period 1 and illustrate the solution (including labor supply as a function of human capital).

# %% [markdown]
# ### Answer 1.2
#
# We will now solve the model for period one.

# %%
def solve_period_1(rho,gamma,beta,Delta,v1,v2_interp):
    
    # Vectors
    l1_vec = np.empty(100)
    v1_vec = np.empty(100)
    
    # Solve for each h1
    for i,h1 in enumerate(h_vec):
             
        # to work or not to work; if utility is higher when not working, then you will not work, else you work
        if v1(h1,1,v2_interp,Delta,w,b,rho,gamma,beta) < v1(h1,0,v2_interp,Delta,w,b,rho,gamma,beta):
            l1_vec[i] = 0
        else:
            l1_vec[i] = 1
        
        v1_vec[i] = v1(h1,l1_vec[i],v2_interp,Delta,w,b,rho,gamma,beta)
        
    return l1_vec, v1_vec

# Construct interpolator
v2_interp = interpolate.RegularGridInterpolator((h_vec,), v2_vec, bounds_error=False, fill_value=None)

# %%
# Symbols
w = sm.symbols('w')
h_1 = sm.symbols('h_1')
rho = sm.symbols('rho')
gamma = sm.symbols('gamma')
v11 = sm.symbols('v_{1, l=1}')
v10 = sm.symbols('v_{1, l=0}')
b = sm.symbols('b')
beta = sm.symbols('beta')
v2 = sm.symbols('E{[v_2]}')

# %%
# Solves for the kink point in human capial i period 2
print(f'Utility when working:')
v_11 = (w*h_1*1)**(1-rho)/(1-rho)-gamma+beta*v2
display(sm.Eq(v11,v_11))
print(f'Utility whn not working:')
v_10 = b**(1-rho)/(1-rho)
display(sm.Eq(v10,v_10))
print(f'The kink in human capital is then where the two utilities are equal, so we set them equal and isolate h_2:')
display(sm.Eq(v_10,v_11))
f1 = v_11-v_10
f1s = sm.solve(f1,h_1)
f1s
# Out:
# Utility when working:
#                                       -ρ + 1
#                                 (h₁⋅w)
# (v_{1, l=1}) = E{[v_2]}⋅β - γ + ────────────
#                                    -ρ + 1
# Utility whn not working:
#                 -ρ + 1
#                b
# (v_{1, l=0}) = ───────
#                 -ρ + 1
# The kink in human capital is then where the two utilities are equal, so we set them equal and isolate h_2:
#  -ρ + 1                          -ρ + 1
# b                          (h₁⋅w)
# ─────── = E{[v_2]}⋅β - γ + ────────────
#  -ρ + 1                       -ρ + 1
# ⎡                                                -1  ⎤
# ⎢                                               ─────⎥
# ⎢                                               ρ - 1⎥
# ⎢⎛                             -ρ + 1          ⎞     ⎥
# ⎢⎝E{[v_2]}⋅β⋅ρ - E{[v_2]}⋅β + b       - γ⋅ρ + γ⎠     ⎥
# ⎢────────────────────────────────────────────────────⎥
# ⎣                         w                          ⎦

# %%
# Breakeven human capital in period 2
rho = 2
beta = 0.96
gamma = 0.1
w = 2
b = 1
h2 = (b**(-rho + 1) - gamma*rho + gamma)**(-1/(rho - 1))/w
print(f'{h2:.4f}')
# Out:
# 0.5556

# %%
#Expected v_2
v2 = (w*h2*1)**(1-rho)/(1-rho)-gamma
print(f'{v2:.20f}')
# Out:
# -0.99999999999999988898

# %%
# Breakeven human capital period 1
print(f'{((v2*beta*rho - v2*beta + (b**(-rho + 1)) - gamma*rho + gamma)**(-1/(rho - 1)))/w:.4f}')
# Out:
# -8.3333

# %% [markdown]
# We know this is not the correct solution, as from the plot below, we see that is should be around 0.35. We suspect that our expected, $E[v_2]$ value is calculated wrong.

# %%
# Solving
l1_vec,v1_vec = solve_period_1(rho,gamma,beta,Delta,v1,v2_interp)

# Figure
fig = plt.figure(figsize=(16,6))
ax = fig.add_subplot(1,2,1)
ax1 = fig.add_subplot(1,2,2)
ax.plot(h_vec,l1_vec)
ax1.plot(h_vec,v1_vec)

# Labels
font = {'family':'serif','color':'darkblue','weight':'normal','size': 16,}
ax.set_xlabel('Human Capital ($h_1$)', fontdict=font)
ax.set_ylabel('Labor supply ($l_1$)', fontdict=font)
ax.set_title('Labor supply as a function of human capital in period 1', fontdict=font)
ax.grid()
ax.plot(0.345,0.5,marker='o') # guess

ax1.set_xlabel('Human Capital ($h_1$)', fontdict=font)
ax1.set_ylabel('Utility ($v_1$)', fontdict=font)
ax1.set_title('Utility as a function of human capital in period 1', fontdict=font)
ax1.grid()
plt.tight_layout()

# %% [markdown]
# We see again that with low human capital you will decide not to work in period two, in fact you will only work if your level of human capital is over 0.345.
#
# Below we have quickly found the kink in human capital with a short analytical solution.

# %% [markdown]
# **Question 3:** Will the worker never work if her potential wage income is lower than the unemployment benefits she can get? Explain and illustrate why or why not.

# %% [markdown]
# ### Answer 1.3

# %% [markdown]
# To investigate if she will choose to never  work, we look at the labor supply as as a functions of potential wages. We choose the highest level of human capital, as we know that higher human capital leads to working. This is because she gets higher utility of higher human capital, and working in the previous period leads to higher human capital in the next period.
#
# We will start by solving period 2.

# %%
rho = 2
beta = 0.96
gamma = 0.1
b = 1
Delta = 0.1

# %%
def utility(c,rho):
    return c**(1-rho)/(1-rho)

def c(w,h,l,b):
    return w*h*l + b*(1-l)

def bequest(l,gamma):
    return gamma*l

def v2(w,h2,l2,b,rho,gamma):
    return utility(c(w,h2,l2,b),rho) - bequest(l2,gamma)

def v1(h1,l1,v2_interp,Delta,w,b,rho,gamma,beta):
    
    # a. v2 value, if no accumulation of humancapital
    h2_No = h1 + l1 + 0
    v2_No = v2_interp([h2_No])[0]
    
    # b. v2 value, if accumulation of human capital
    h2_Yes = h1 + l1 + Delta
    v2_Yes = v2_interp([h2_Yes])[0]
    
    # c. expected v2 value
    v2 = 0.5*v2_No + 0.5*v2_Yes
    
    # d. total value
    return utility(c(w,h1,l1,b),rho) - bequest(l1,gamma) + beta*v2

# %% [markdown]
# The function for period 2 is now dependent on a vector of values for income wage from approximately zero to two.

# %%
h2 = 1.5
w_vec = np.linspace(1e-8,2,100)

def solve_period_2_2(rho,gamma,Delta):
    
    # Vectors
    l2_vec = np.empty(100)
    v2_vec = np.empty(100)
    
    # Solve for each h2
    for i,w in enumerate(w_vec):
        
        # to work or not to work
        if v2(w,h2,1,b,rho,gamma) < v2(w,h2,0,b,rho,gamma):
            l2_vec[i] = 0
        else:
            l2_vec[i] = 1
        
        v2_vec[i] = v2(w,h2,l2_vec[i],b,rho,gamma)
        
    return l2_vec, v2_vec

# %%
# Symbols
w = sm.symbols('w')
h_2 = sm.symbols('h_2')
rho = sm.symbols('rho')
gamma = sm.symbols('gamma')
v21 = sm.symbols('v_{2, l=1}')
v20 = sm.symbols('v_{2, l=0}')
b = sm.symbols('b')

# %%
# Solves for the kink point in income wage i period 2
print(f'Utility when working:')
v_21 = (w*h_2*1)**(1-rho)/(1-rho)-gamma
display(sm.Eq(v21,v_21))
print(f'Utility whn not working:')
v_20 = b**(1-rho)/(1-rho)
display(sm.Eq(v20,v_20))
print(f'The kink in income wage is then where the two utilities are equal, so we set them equal and isolate w:')
display(sm.Eq(v_20,v_21))
f = v_21-v_20
fs = sm.solve(f,w)
print(fs)
fs
# Out:
# Utility when working:
#                           -ρ + 1
#                     (h₂⋅w)
# (v_{2, l=1}) = -γ + ────────────
#                        -ρ + 1
# Utility whn not working:
#                 -ρ + 1
#                b
# (v_{2, l=0}) = ───────
#                 -ρ + 1
# The kink in income wage is then where the two utilities are equal, so we set them equal and isolate w:
#  -ρ + 1              -ρ + 1
# b              (h₂⋅w)
# ─────── = -γ + ────────────
#  -ρ + 1           -ρ + 1
# [(b**(-rho + 1) - gamma*rho + gamma)**(-1/(rho - 1))/h_2]
# ⎡                    -1  ⎤
# ⎢                   ─────⎥
# ⎢                   ρ - 1⎥
# ⎢⎛ -ρ + 1          ⎞     ⎥
# ⎢⎝b       - γ⋅ρ + γ⎠     ⎥
# ⎢────────────────────────⎥
# ⎣           h₂           ⎦

# %%
rho = 2
beta = 0.96
gamma = 0.1
h_2 = 1.5
b = 1
w = (b**(-rho + 1) - gamma*rho + gamma)**(-1/(rho - 1))/h_2
print(f'{w:.4f}')
# Out:
# 0.7407

# %%
# Solving
l2_vec,v2_vec = solve_period_2_2(rho,gamma,Delta)

# Figure
fig = plt.figure(figsize=(16,6))
ax = fig.add_subplot(1,2,1)
ax1 = fig.add_subplot(1,2,2)
ax.plot(w_vec,l2_vec)
ax1.plot(w_vec,v2_vec)

# Labels
font = {'family':'serif','color':'darkblue','weight':'normal','size': 16,}
ax.set_xlabel('Income wage ($w$)', fontdict=font)
ax.set_ylabel('Labor supply ($l_2$)', fontdict=font)
ax.set_title('Labor supply as a function of wage income in period 2', fontdict=font)
ax.grid()
ax.plot(w,0.5,marker='o')

ax1.set_xlabel('Income wage ($w$)', fontdict=font)
ax1.set_ylabel('Utility ($v_2$)', fontdict=font)
ax1.set_title('Utility as a function of wage income in period 2', fontdict=font)
ax1.grid()

# %% [markdown]
# If the wage is below 0.741 no one will work in period 2, if she have a lower level of human capital than 1.5. This limit will increase, meaning lower human capital leads to higher wage demand. As utility decrease with the level of human capital, the wage will have to increase for she to choose to work.

# %% [markdown]
# Now we will solve for period 1, using the same the same procedure as above.

# %%
h1 = 1.5

def solve_period_1_2(rho,gamma,beta,Delta,v1,v2_interp):
    
    # Vectors
    l1_vec = np.empty(100)
    v1_vec = np.empty(100)
    
    # Solve for each h1
    for i,w in enumerate(w_vec):
             
        # to work or not to work; if utility is higher when not working, then you will not work, else you work
        if v1(h1,1,v2_interp,Delta,w,b,rho,gamma,beta) < v1(h1,0,v2_interp,Delta,w,b,rho,gamma,beta):
            l1_vec[i] = 0
        else:
            l1_vec[i] = 1
        
        v1_vec[i] = v1(h1,l1_vec[i],v2_interp,Delta,w,b,rho,gamma,beta)
        
    return l1_vec, v1_vec

# Construct interpolator
v2_interp = interpolate.RegularGridInterpolator((w_vec,), v2_vec, bounds_error=False, fill_value=None)

# %%
# Symbols
w = sm.symbols('w')
h_1 = sm.symbols('h_1')
rho = sm.symbols('rho')
gamma = sm.symbols('gamma')
v11 = sm.symbols('v_{1, l=1}')
v10 = sm.symbols('v_{1, l=0}')
b = sm.symbols('b')
beta = sm.symbols('beta')
v2 = sm.symbols('E{[v_2]}')

# %%
# Solves for the kink point in human capial i period 2
print(f'Utility when working:')
v_11 = (w*h_1*1)**(1-rho)/(1-rho)-gamma+beta*v2
display(sm.Eq(v11,v_11))
print(f'Utility whn not working:')
v_10 = b**(1-rho)/(1-rho)
display(sm.Eq(v10,v_10))
print(f'The kink in human capital is then where the two utilities are equal, so we set them equal and isolate h_2:')
display(sm.Eq(v_10,v_11))
f1 = v_11-v_10
f1s = sm.solve(f1,w)
print(f1s)
f1s
# Out:
# Utility when working:
#                                       -ρ + 1
#                                 (h₁⋅w)
# (v_{1, l=1}) = E{[v_2]}⋅β - γ + ────────────
#                                    -ρ + 1
# Utility whn not working:
#                 -ρ + 1
#                b
# (v_{1, l=0}) = ───────
#                 -ρ + 1
# The kink in human capital is then where the two utilities are equal, so we set them equal and isolate h_2:
#  -ρ + 1                          -ρ + 1
# b                          (h₁⋅w)
# ─────── = E{[v_2]}⋅β - γ + ────────────
#  -ρ + 1                       -ρ + 1
# [(E{[v_2]}*beta*rho - E{[v_2]}*beta + b**(-rho + 1) - gamma*rho + gamma)**(-1/(rho - 1))/h_1]
# ⎡                                                -1  ⎤
# ⎢                                               ─────⎥
# ⎢                                               ρ - 1⎥
# ⎢⎛                             -ρ + 1          ⎞     ⎥
# ⎢⎝E{[v_2]}⋅β⋅ρ - E{[v_2]}⋅β + b       - γ⋅ρ + γ⎠     ⎥
# ⎢────────────────────────────────────────────────────⎥
# ⎣                         h₁                         ⎦

# %%
rho = 2
beta = 0.96
gamma = 0.1
h2 = 1.5
b = 1
w = (b**(-rho + 1) - gamma*rho + gamma)**(-1/(rho - 1))/h2
print(f'{w:.4f}')
# Out:
# 0.7407

# %%
#Expected v_2
v2 = (w*h2*1)**(1-rho)/(1-rho)-gamma
print(f'{v2:.20f}')
# Out:
# -0.99999999999999988898

# %%
h1 = 1.5
print(f'{(v2*beta*rho - v2*beta + b**(-rho + 1) - gamma*rho + gamma)**(-1/(rho - 1))/h1:.4f}')
# Out:
# -11.1111

# %%
# Solving
l1_vec,v1_vec = solve_period_1_2(rho,gamma,beta,Delta,v1,v2_interp)

# Figure
fig = plt.figure(figsize=(16,6))
ax = fig.add_subplot(1,2,1)
ax1 = fig.add_subplot(1,2,2)
ax.plot(w_vec,l1_vec)
ax1.plot(w_vec,v1_vec)

# Labels
font = {'family':'serif','color':'darkblue','weight':'normal','size': 16,}
ax.set_xlabel('Income wage ($w$)', fontdict=font)
ax.set_ylabel('Labor supply ($l_1$)', fontdict=font)
ax.set_title('Labor supply as a function of income wage in period 1', fontdict=font)
ax.grid()
ax.plot(0.61,0.5,marker='o') # guess

ax1.set_xlabel('Income wage ($w$)', fontdict=font)
ax1.set_ylabel('Utility ($v_1$)', fontdict=font)
ax1.set_title('Utility as a function of income wage in period 1', fontdict=font)
ax1.grid()

# %% [markdown]
# Our numerical analysis fails again, most likely for the same reason as before.
#
# But we have illustrated labor supply and utility as a function of income wage, we see that the level of income wage to start working, is lower in period one than in period two. This is due to her now being able to accumulate human capital over two periods, instead of just one.

# %% [markdown]
# # AS-AD model

# %% [markdown]
# Consider the following **AS-AD model**. The **goods market equilibrium** is given by
#
# $$ y_{t} = -\alpha r_{t} + v_{t} $$
#
# where $y_{t}$ is the **output gap**, $r_{t}$ is the **ex ante real interest** and $v_{t}$ is a **demand disturbance**.

# %% [markdown]
# The central bank's **Taylor rule** is
#
# $$ i_{t} = \pi_{t+1}^{e} + h \pi_{t} + b y_{t}$$
#
# where $i_{t}$ is the **nominal interest rate**, $\pi_{t}$ is the **inflation gap**, and $\pi_{t+1}^{e}$ is the **expected inflation gap**.

# %% [markdown]
# The **ex ante real interest rate** is given by
#
# $$ r_{t} = i_{t} - \pi_{t+1}^{e} $$

# %% [markdown]
# Together, the above implies that the **AD-curve** is
#
# $$ \pi_{t} = \frac{1}{h\alpha}\left[v_{t} - (1+b\alpha)y_{t}\right]$$

# %% [markdown]
# Further, assume that the **short-run supply curve (SRAS)** is given by
#
# $$ \pi_{t} = \pi_{t}^{e} + \gamma y_{t} + s_{t}$$
#
# where $s_t$ is a **supply disturbance**.

# %% [markdown]
# **Inflation expectations are adaptive** and given by
#
# $$ \pi_{t}^{e} = \phi\pi_{t-1}^{e} + (1-\phi)\pi_{t-1}$$

# %% [markdown]
# Together, this implies that the **SRAS-curve** can also be written as
#
# $$ \pi_{t} = \pi_{t-1} + \gamma y_{t} - \phi\gamma y_{t-1} + s_{t} - \phi s_{t-1} $$

# %% [markdown]
# The **parameters** of the model are:

# %%
par = {}

par['alpha'] = 5.76
par['h'] = 0.5
par['b'] = 0.5
par['phi'] = 0
par['gamma'] = 0.075

# %% [markdown]
# In the following questions we have used inspiration from problem set 2 and 7, aswell as  lecture 9.

# %% [markdown]
# ## **Answer 2**: AS-AD Model

# %% [markdown]
# **Question 1:** Use the ``sympy`` module to solve for the equilibrium values of output, $y_t$, and inflation, $\pi_t$, (where AD = SRAS) given the parameters ($\alpha$, $h$, $b$, $\alpha$, $\gamma$) and $y_{t-1}$ , $\pi_{t-1}$, $v_t$, $s_t$, and $s_{t-1}$.

# %% [markdown]
# ### **Answer 2.1:**
#
# We start by defining the sympy symbols and afterwards the model functions.

# %%
# Defining variables for sympy math symbols

# Variables
y_t = sm.symbols('y_t')
r_t = sm.symbols('r_t')
v_t = sm.symbols('v_t')
i_t = sm.symbols('i_t')
pie_plus = sm.symbols('\pi^e_{t+1}')
pi_t = sm.symbols('pi_t')
pie_t = sm.symbols('\pi^e_t')
s_t = sm.symbols('s_t')
pie_minus = sm.symbols('\pi^e_{t-1}')
pi_minus = sm.symbols('\pi_{t-1}')
y_minus = sm.symbols('y_{t-1}')
s_minus = sm.symbols('s_{t-1}')

# Parameters
alpha = sm.symbols('alpha')
h = sm.symbols('h')
b = sm.symbols('b')
gamma = sm.symbols('gamma')
phi = sm.symbols('phi')

# %% [markdown]
# The model functions.

# %%
print(f'The goods market equilibrium:')
fy_t = -alpha*r_t+v_t
display(sm.Eq(y_t,fy_t))
print(f'The Taylor rule:')
fi_t = pie_plus + h*pi_t + b*y_t
display(sm.Eq(i_t,fi_t))
print(f'The ex ante real interest rate:')
fr_t = i_t - pie_plus
display(sm.Eq(r_t,fr_t))
print(f'The AD-curve:')
fpi_t_AD = (1/(h*alpha))*(v_t - (1 + b*alpha)*y_t)
display(sm.Eq(pi_t,fpi_t_AD))
print(f'The short-run supply curve (SRAS):')
fpi_t_SRAS = pie_t + gamma*y_t + s_t
display(sm.Eq(pi_t,fpi_t_SRAS))
print(f'Inflation expectations:')
fpie_t_in = phi*pie_minus + (1 - phi)*pi_minus
display(sm.Eq(pie_t,fpie_t_in))
print(f'SRAS-curve with inflation expectations:')
fpi_t_SRAS_in = pi_minus + gamma*y_t - phi*gamma*y_minus + s_t - phi*s_minus
display(sm.Eq(pi_t,fpi_t_SRAS_in))
# Out:
# The goods market equilibrium:
# yₜ = -α⋅rₜ + vₜ
# The Taylor rule:
# iₜ = \pi_{t+1}__e + b⋅yₜ + h⋅πₜ
# The ex ante real interest rate:
# rₜ = -\pi_{t+1}__e + iₜ
# The AD-curve:
#      vₜ - yₜ⋅(α⋅b + 1)
# πₜ = ─────────────────
#             α⋅h
# The short-run supply curve (SRAS):
# πₜ = \pi_t__e + γ⋅yₜ + sₜ
# Inflation expectations:
# \pi_t__e = \pi_{t-1}__e⋅φ + \pi_{t-1}⋅(-φ + 1)
# SRAS-curve with inflation expectations:
# πₜ = \pi_{t-1} - γ⋅φ⋅y_{t-1} + γ⋅yₜ - φ⋅s_{t-1} + sₜ

# %% [markdown]
# We will now solve for the equilibrium value of output, \$y_t$, by setting the SRAS-curve and AD-curve equal to each other.

# %%
SRAS_curve = fpi_t_SRAS_in
AD_curve = fpi_t_AD

# Equalizing
print(f'AD=SRAS')
equal =  AD_curve-SRAS_curve
display(sm.Eq(AD_curve,SRAS_curve))

# Solving the model
equal_solve_y = sm.solve(equal,y_t)[0]
display(sm.Eq(y_t,equal_solve_y))
# Out:
# AD=SRAS
# vₜ - yₜ⋅(α⋅b + 1)
# ───────────────── = \pi_{t-1} - γ⋅φ⋅y_{t-1} + γ⋅yₜ - φ⋅s_{t-1} + sₜ
#        α⋅h
#      -\pi_{t-1}⋅α⋅h + α⋅γ⋅h⋅φ⋅y_{t-1} + α⋅h⋅φ⋅s_{t-1} - α⋅h⋅sₜ + vₜ
# yₜ = ──────────────────────────────────────────────────────────────
#                             α⋅b + α⋅γ⋅h + 1

# %% [markdown]
# We will insert our equilibrium value of output into the SRAS-curve function to find the equilibrium of $\pi_t$.

# %%
print(f'SRAS-curve, with solved y_t:')
SRAS_curve_solve_y = pi_minus + gamma*equal_solve_y - phi*gamma*y_minus + s_t - phi*s_minus
display(sm.Eq(pi_t,SRAS_curve_solve_y))
# Out:
# SRAS-curve, with solved y_t:
#                                γ⋅(-\pi_{t-1}⋅α⋅h + α⋅γ⋅h⋅φ⋅y_{t-1} + α⋅h⋅φ⋅s_{
# πₜ = \pi_{t-1} - γ⋅φ⋅y_{t-1} + ───────────────────────────────────────────────
#                                                         α⋅b + α⋅γ⋅h + 1
#
# t-1} - α⋅h⋅sₜ + vₜ)
# ─────────────────── - φ⋅s_{t-1} + sₜ

# %% [markdown]
# We have now solved for the equilibrium values of output and inflation given parameters and the variables stated in the question.

# %% [markdown]
# **Question 2:** Find and illustrate the equilibrium when $y_{t-1} = \pi_{t-1} = v_t = s_t = s_{t-1} = 0$. Illustrate how the equilibrium changes when instead $v_t = 0.1$.

# %% [markdown]
# ### **Answer 2.2:**
#
# We now set the variables to equal to 0 and calculate the equilibrium values for the output gap and inflation gap.

# %%
print(equal_solve_y)
equal_solve_y
# Out:
# (-\pi_{t-1}*alpha*h + alpha*gamma*h*phi*y_{t-1} + alpha*h*phi*s_{t-1} - alpha*h*s_t + v_t)/(alpha*b + alpha*gamma*h + 1)
# -\pi_{t-1}⋅α⋅h + α⋅γ⋅h⋅φ⋅y_{t-1} + α⋅h⋅φ⋅s_{t-1} - α⋅h⋅sₜ + vₜ
# ──────────────────────────────────────────────────────────────
#                        α⋅b + α⋅γ⋅h + 1

# %%
(-0*alpha*h + alpha*gamma*h*phi*0 + alpha*h*phi*0 - alpha*h*0 + 0)/(alpha*b + alpha*gamma*h + 1)
# Out:
# 0

# %%
print(SRAS_curve_solve_y)
SRAS_curve_solve_y
# Out:
# \pi_{t-1} - gamma*phi*y_{t-1} + gamma*(-\pi_{t-1}*alpha*h + alpha*gamma*h*phi*y_{t-1} + alpha*h*phi*s_{t-1} - alpha*h*s_t + v_t)/(alpha*b + alpha*gamma*h + 1) - phi*s_{t-1} + s_t
#                           γ⋅(-\pi_{t-1}⋅α⋅h + α⋅γ⋅h⋅φ⋅y_{t-1} + α⋅h⋅φ⋅s_{t-1}
# \pi_{t-1} - γ⋅φ⋅y_{t-1} + ────────────────────────────────────────────────────
#                                                    α⋅b + α⋅γ⋅h + 1
#
# - α⋅h⋅sₜ + vₜ)
# ────────────── - φ⋅s_{t-1} + sₜ

# %%
0 - gamma*phi*0 + gamma*(-0*alpha*h + alpha*gamma*h*phi*0 + alpha*h*phi*0 - alpha*h*0 + 0)/(alpha*b + alpha*gamma*h + 1) - phi*0 + 0
# Out:
# 0

# %% [markdown]
# To get a closer look we start by defining the variable values that we were given.

# %%
# Variable values
var = {}

var['y_minus'] = 0
var['pi_minus'] = 0
var['s_minus'] = 0
var['s'] = 0
var['v'] = 0
var['v_new'] = 0.1

# %%
print(f'Values of the output gap and the inflation gap, with no shocks:')
# y
y_value = sm.lambdify((alpha,h,b,phi,gamma,y_minus,pi_minus,s_minus, s_t,v_t),equal_solve_y)
y_print = y_value(par['alpha'], par['h'],par['b'],par['phi'],par['gamma'],var['y_minus'],var['pi_minus'],var['s_minus'],var['s'],var['v'])
print(f'The EQ value of the output gap is {y_print}')

# pi
pi_value = sm.lambdify((alpha,h,b,phi,gamma,y_minus,pi_minus,s_minus, s_t,v_t),SRAS_curve_solve_y)
pi_print = pi_value(par['alpha'], par['h'],par['b'],par['phi'],par['gamma'],var['y_minus'],var['pi_minus'],var['s_minus'],var['s'],var['v'])
print(f'The EQ value of the inflation gap is {pi_print}')
# Out:
# Values of the output gap and the inflation gap, with no shocks:
# The EQ value of the output gap is 0.0
# The EQ value of the inflation gap is 0.0

# %%
# y with demand shock
print(f'Values of the output gap and the inflation gap, with demand shock of 0.1:')
y_value = sm.lambdify((alpha,h,b,phi,gamma,y_minus,pi_minus,s_minus, s_t,v_t),equal_solve_y)
y_print = y_value(par['alpha'], par['h'],par['b'],par['phi'],par['gamma'],var['y_minus'],var['pi_minus'],var['s_minus'],var['s'],var['v_new'])
print(f'The value of the output gap is {y_print}')

# pi with demand shock
pi_value = sm.lambdify((alpha,h,b,phi,gamma,y_minus,pi_minus,s_minus, s_t,v_t),SRAS_curve_solve_y)
pi_print = pi_value(par['alpha'], par['h'],par['b'],par['phi'],par['gamma'],var['y_minus'],var['pi_minus'],var['s_minus'],var['s'],var['v_new'])
print(f'The value of the inflation gap is {pi_print}')
# Out:
# Values of the output gap and the inflation gap, with demand shock of 0.1:
# The value of the output gap is 0.0244140625
# The value of the inflation gap is 0.0018310546875

# %% [markdown]
# When all the parameters are equal to 0, we see that the equilibrium values are also 0. This makes great sense, as we are in equilibrium and there shouldn't be a gap. The economy is now hit by a demand shock, $v_t = 0.1$ and we now see positive gaps in both output and inflation. This is in accordance with economic theory.

# %% [markdown]
# Now we want to illustrate the AD-SRAS curve, so we define the two functions.

# %%
# Defining the AD and SRAS functions
def AD(y_t,h,b,alpha,v_t):
    return (1/(h*alpha))*(v_t - (1 + b*alpha)*y_t)

def SRAS(pi_minus,gamma,y_t,phi,y_minus,s_t,s_minus):
    return pi_minus + gamma*y_t - phi*gamma*y_minus + s_t - phi*s_minus

# %% [markdown]
# We now define the plot, including a slider so we can change between $v_t = 0$ $and$ $v_t = 0.1$

# %%
#Defining plot
def AD_AS_plot(v_value):

    y_lin = np.linspace(-0.2,0.2,100)
    AD_curve = AD(y_t=y_lin,h=par['h'],b=par['b'],alpha=par['alpha'],v_t=v_value)
    AD_curve_v = AD(y_t=y_lin,h=par['h'],b=par['b'],alpha=par['alpha'],v_t=v_value+0.1)
    SRAS_curve = SRAS(pi_minus=var['pi_minus'], gamma=par['gamma'], y_t=y_lin, phi=par['phi'], y_minus=var['y_minus'], s_t=var['s'], s_minus=var['s_minus'])
    
    font = {'family':'serif','color':'darkblue','weight':'normal','size': 18,}

    plt.figure(figsize=(12,8))
    plt.plot(y_lin,AD_curve)
    plt.plot(y_lin,AD_curve_v)
    plt.plot(y_lin,SRAS_curve)
    plt.title('Illustration of AD & SRAS',fontdict=font)
    plt.grid(True)
    plt.xlabel('Output gap',fontdict=font)
    plt.ylabel('Inflation gap',fontdict=font)
    plt.legend(('AD - no shock', 'AD - demand shock', 'SRAS'), loc='best',prop={'size':18})
    
    return plt

plt.show(AD_AS_plot(0))

# %% [markdown]
# From the figure above, we see that it is only the AD curve initially changes, when the economy is hit by a demand shock. It shifts right and the inflation and output increases initially.
#
# The figure also shows us the equilibrium we found earlier: No shock (0,0) and with shock (0.025 , 0.002)

# %% [markdown]
# **Persistent disturbances:** Now, additionaly, assume that both the demand and the supply disturbances are AR(1) processes
#
# $$ v_{t} = \delta v_{t-1} + x_{t} $$
# $$ s_{t} = \omega s_{t-1} + c_{t} $$
#
# where $x_{t}$ is a **demand shock**, and $c_t$ is a **supply shock**. The **autoregressive parameters** are:

# %%
par['delta'] = 0.80
par['omega'] = 0.15

# %% [markdown]
# **Question 3:** Starting from $y_{-1} = \pi_{-1} = s_{-1} = 0$, how does the economy evolve for $x_0 = 0.1$, $x_t = 0, \forall t > 0$ and $c_t = 0, \forall t \geq 0$?

# %% [markdown]
# ### **Answer 2.3:**

# %% [markdown]
# We are now given new information about how the demand and supply shocks behave. They are now given by AR(1) processes. We will start by defining this new addition to the model.

# %%
# Defining new shocks
def v_t(v_minus,x):
    return par['delta']*v_minus+x
def s_t(s_minus,c):
    return par['omega']*s_minus+c

# %% [markdown]
# We started off limiting our model to 10 periods. But after running the simulation once, we saw that we didn't get back to equilibrium. Instead we will set $T$ to $100$.
# Also we will set $x_0$ to be equal to $0.1$.

# %%
# Definging periods, vectors, c, x and x_0
T = 100
y_vec = [0]
pi_vec = [0]
v_vec = [0]
s_vec = [0]
c_vec = np.zeros(T)
x_vec = np.zeros(T)
x_vec[1] = 0.1 # the first period is t-1

# %%
# Simulation of AD-AS Model
for t in range(1,T):
    
    v_vec.append(v_t(v_vec[t-1], x_vec[t]))
    s_vec.append(s_t(s_vec[t-1], c_vec[t]))
    y_vec.append(y_value(par['alpha'], par['h'],par['b'],par['phi'],par['gamma'],y_vec[t-1],pi_vec[t-1],s_vec[t-1],s_vec[t],v_vec[t]))
    pi_vec.append(pi_value(par['alpha'], par['h'],par['b'],par['phi'],par['gamma'],y_vec[t-1],pi_vec[t-1],s_vec[t-1],s_vec[t],v_vec[t]))

# %%
# Creating a figure
periods = np.linspace(0,T,T)

plot = plt.figure(figsize=(8,12))

font = {'family':'serif','color':'darkblue','weight':'normal','size': 18,}

ax = plot.add_subplot(311)
ax2 = plot.add_subplot(312)
ax3 = plot.add_subplot(313)

ax.plot(y_vec,pi_vec)
ax.set_title('Output gap and Inflation Gap',fontdict=font)
ax.set_xlabel('Output gap',fontdict=font)
ax.set_ylabel('Inflation gap',fontdict=font)
ax.grid(linestyle='--', linewidth=1)

ax2.plot(periods,y_vec)
ax2.set_title('Output gap development over T periods',fontdict=font)
ax2.set_xlabel('Time',fontdict=font)
ax2.set_ylabel('Output gap',fontdict=font)
ax2.grid(linestyle='--', linewidth=1)

ax3.plot(periods,pi_vec)
ax3.set_title('Inflation gap development over T periods',fontdict=font)
ax3.set_xlabel('Time',fontdict=font)
ax3.set_ylabel('Inflation gap',fontdict=font)
ax3.grid(linestyle='--', linewidth=1)

plt.tight_layout()

# %% [markdown]
# From the above figure, we see that in period 0 the economy gets hit by a shock. This from the $x_0$ value of 0.1. Compared to the model from last question, where we see the shock hit the economy, but immediately the period after, returns to the equilibrium. We now see convergence in the economy over time.

# %% [markdown]
# **Stochastic shocks:** Now, additionally, assume that $x_t$ and $c_t$ are stochastic and normally distributed
#
# $$ x_{t}\sim\mathcal{N}(0,\sigma_{x}^{2}) $$
# $$ c_{t}\sim\mathcal{N}(0,\sigma_{c}^{2}) $$
#
# The **standard deviations of the shocks** are:

# %%
par['sigma_x'] = 3.492
par['sigma_c'] = 0.2

# %% [markdown]
# **Question 4:** Simulate the AS-AD model for 1,000 periods. Calculate the following five statistics:
#
# 1. Variance of $y_t$, $var(y_t)$
# 2. Variance of $\pi_t$, $var(\pi_t)$
# 3. Correlation between $y_t$ and $\pi_t$, $corr(y_t,\pi_t)$
# 4. Auto-correlation between $y_t$ and $y_{t-1}$, $corr(y_t,y_{t-1})$
# 5. Auto-correlation between $\pi_t$ and $\pi_{t-1}$, $corr(\pi_t,\pi_{t-1})$

# %% [markdown]
# ### **Answer 2.4:**

# %% [markdown]
# We are now given additional new information about how the stochastic shocks are distributed. We are given these standard deviations above.

# %%
# Defining periods, vectors, c, x and x_0
seed = 2019
np.random.seed(seed)

T = 1000
y_vec2 = [0]
pi_vec2 = [0]
v_vec2 = [0]
s_vec2 = [0]
x_vec2 = np.random.normal(loc=0,scale=par['sigma_x'],size=T)
c_vec2 = np.random.normal(loc=0,scale=par['sigma_c'],size=T)

# %%
# Simulation of AD-AS Model
for t in range(1,T):
    
    v_vec2.append(v_t(v_vec2[t-1], x_vec2[t]))
    s_vec2.append(s_t(s_vec2[t-1], c_vec2[t]))
    
    y_vec2.append(y_value(par['alpha'], par['h'],par['b'],par['phi'],par['gamma'],y_vec2[t-1],pi_vec2[t-1],s_vec2[t-1],s_vec2[t],v_vec2[t]))
    pi_vec2.append(pi_value(par['alpha'], par['h'],par['b'],par['phi'],par['gamma'],y_vec2[t-1],pi_vec2[t-1],s_vec2[t-1],s_vec2[t],v_vec2[t]))

# %%
# Creating a figure
periods2 = np.linspace(0,T,T)

font = {'family':'serif','color':'darkblue','weight':'normal','size': 18,}

plot2 = plt.figure(figsize=(8,12))

ax = plot2.add_subplot(311)
ax2 = plot2.add_subplot(312)
ax3 = plot2.add_subplot(313)

ax.plot(y_vec2,pi_vec2)
ax.set_title('Output gap and Inflation Gap',fontdict=font)
ax.set_xlabel('Output gap',fontdict=font)
ax.set_ylabel('Inflation gap',fontdict=font)
ax.grid(linestyle='--', linewidth=1)

ax2.plot(periods2,y_vec2)
ax2.set_title('Output gap development over T periods',fontdict=font)
ax2.set_xlabel('Periods',fontdict=font)
ax2.set_ylabel('Output gap',fontdict=font)
ax2.grid(linestyle='--', linewidth=1)

ax3.plot(periods2,pi_vec2)
ax3.set_title('Inflation gap development over T periods',fontdict=font)
ax3.set_xlabel('Periods',fontdict=font)
ax3.set_ylabel('Inflation gap',fontdict=font)
ax3.grid(linestyle='--', linewidth=1)

plt.tight_layout()

# %% [markdown]
# Looking at first plot above, we now see that output and inflation moves around a lot, compared to the model before. Compared to the model before, we now have an economy that is constantly hit, by small shocks on both demand and supply and the model. Whereas the model before was only hit once and then the shock disappears over time. We can also see that the gaps are now mean reverting and can be seen as stationary. We will now move on to find the five statistics.

# %%
y_pi_corr = np.corrcoef(y_vec2,pi_vec2)
y_auto = np.corrcoef(y_vec2[1:],y_vec2[:-1])
pi_auto = np.corrcoef(pi_vec2[1:],pi_vec2[:-1])

print(f'The variance of the output gap is: var(y_t) = {np.var(y_vec2):.4f}')
print(f'The variance of the inflation gap is: var(pi_t) = {np.var(pi_vec2):.4f}')
print(f'The correlation between the output gap and the inflation gap is: corr(y_t,pi_t) = {y_pi_corr[0,1]:.4f}')
print(f'The autocorrelation between the output gap and the ougput gap in the previous period is: corr(y_t,y_t-1) = {y_auto[0,1]:.4f}')
print(f'The autocorrelation between the inflation gap and the inflation gap in the previous period is: corr(pi_t,pi_t-1) = {pi_auto[0,1]:.4f}')
# Out:
# The variance of the output gap is: var(y_t) = 1.9603
# The variance of the inflation gap is: var(pi_t) = 0.9640
# The correlation between the output gap and the inflation gap is: corr(y_t,pi_t) = -0.1634
# The autocorrelation between the output gap and the ougput gap in the previous period is: corr(y_t,y_t-1) = 0.7672
# The autocorrelation between the inflation gap and the inflation gap in the previous period is: corr(pi_t,pi_t-1) = 0.9767

# %% [markdown]
# **Question 5:** Plot how the correlation between $y_t$ and $\pi_t$ changes with $\phi$. Use a numerical optimizer or root finder to choose $\phi\in(0,1)$ such that the simulated correlation between $y_t$ and $\pi_t$ comes close to 0.31.

# %% [markdown]
# ### **Answer 2.5:**

# %% [markdown]
# In order to plot the correlation, we will create a simulation that, creates different y values and pi values, but all other parameters equal to the earlier questions. To do this, we will simulate the results by creating a simulation

# %%
# Setting seed, periods and simulation x and c
seed = 2019
np.random.seed(seed)

T = 1000
x_vec3 = np.random.normal(loc=0,scale=par['sigma_x'],size=T)
c_vec3 = np.random.normal(loc=0,scale=par['sigma_c'],size=T)

# %%
# Simulation of AS-AD Model with change in phi
def simulation_phi(phi):
    y_vec3 = [0]
    pi_vec3 = [0]
    v_vec3 = [0]
    s_vec3 = [0]
    y_pi_corr2 = [0]
    for t in range(1,T):

        v_vec3.append(v_t(v_vec3[t-1], x_vec3[t]))
        s_vec3.append(s_t(s_vec3[t-1], c_vec3[t]))
    
        y_vec3.append(y_value(par['alpha'], par['h'],par['b'],phi,par['gamma'],y_vec3[t-1],pi_vec3[t-1],s_vec3[t-1],s_vec3[t],v_vec3[t]))
        pi_vec3.append(pi_value(par['alpha'], par['h'],par['b'],phi,par['gamma'],y_vec3[t-1],pi_vec3[t-1],s_vec3[t-1],s_vec3[t],v_vec3[t]))
   
            
    y_pi_corr2 = np.corrcoef(y_vec3, pi_vec3)[1,0]
    
    return y_vec3, pi_vec3, y_pi_corr2

y_vec3, pi_vec3, y_pi_corr2 = simulation_phi(par['phi'])

# %% [markdown]
# We will now simulate the model for $\phi$ to create the plot data for the correlation between $y$ and $\pi$. After this we will plot the change in correlation and comment.

# %%
#Simulating plot data
phi_plot = np.linspace(1e-8,1,T)
corr_plot = []

for x in phi_plot:
    y_vec3, pi_vec3, y_pi_corr2 = simulation_phi(x)
    corr_plot.append(y_pi_corr2)

# %%
# Plotting correlation
plt.figure(dpi=100)
plt.xlabel('$\phi$')
plt.ylabel('Correlation')
plt.title('Figure showing correlation between $y$ and $pi$')
plt.plot(phi_plot,corr_plot, color = 'lightblue')
plt.legend('Correlation', loc='best')
plt.grid()
plt.show()
plt.tight_layout()

# %% [markdown]
# From the figure above, we see that when the correlation is around 0.31, that we have a $\phi$ of approx 0.95. We also see, that the correlation is increasing in $\phi$. We will now use sympy optimizer to find the value of $\phi$ that creates a correlation between $y$ and $\pi$ of exactly $0.31$

# %%
obj_phi = lambda phi: np.corrcoef(simulation_phi(phi)[0], simulation_phi( phi)[1])[1,0] - 0.31

result = optimize.root_scalar(obj_phi, x0 = 0.9, bracket = [0,1], method = 'brentq')

phi_opt = result.root
print(f'The optimized phi is, {phi_opt:.4f}')
print(f'Test for correlation of this phi is, {np.corrcoef(simulation_phi(phi_opt)[0], simulation_phi(phi_opt)[1])[1,0]:.4f}')
# Out:
# The optimized phi is, 0.9449
# Test for correlation of this phi is, 0.3100

# %% [markdown]
# This results makes sense when we look at the figure above. We also set out initial guess, close enough, as we could see on the figure, that it was close to 0.9

# %% [markdown]
# **Quesiton 6:** Use a numerical optimizer to choose $\sigma_x>0$, $\sigma_c>0$ and $\phi\in(0,1)$ to make the simulated statistics as close as possible to US business cycle data where:
#
# 1. $var(y_t) = 1.64$
# 2. $var(\pi_t) = 0.21$
# 3. $corr(y_t,\pi_t) = 0.31$
# 4. $corr(y_t,y_{t-1}) = 0.84$
# 5. $corr(\pi_t,\pi_{t-1}) = 0.48$

# %% [markdown]
# ### **Answer 2.6:**

# %% [markdown]
# # Exchange economy

# %% [markdown]
# Consider an **exchange economy** with
#
# 1. 3 goods, $(x_1,x_2,x_3)$
# 2. $N$ consumers indexed by \\( j \in \{1,2,\dots,N\} \\)
# 3. Preferences are Cobb-Douglas with log-normally distributed coefficients
#
#     $$ \begin{eqnarray*}
#     u^{j}(x_{1},x_{2},x_{3}) &=&
#     \left(x_{1}^{\beta_{1}^{j}}x_{2}^{\beta_{2}^{j}}x_{3}^{\beta_{3}^{j}}\right)^{\gamma}\\
#      &  & \,\,\,\beta_{i}^{j}=\frac{\alpha_{i}^{j}}{\alpha_{1}^{j}+\alpha_{2}^{j}+\alpha_{3}^{j}} \\
#      &  & \,\,\,\boldsymbol{\alpha}^{j}=(\alpha_{1}^{j},\alpha_{2}^{j},\alpha_{3}^{j}) \\
#      &  & \,\,\,\log(\boldsymbol{\alpha}^j) \sim \mathcal{N}(\mu,\Sigma) \\
#     \end{eqnarray*} $$
#
# 4. Endowments are exponentially distributed,
#
# $$
# \begin{eqnarray*}
# \boldsymbol{e}^{j} &=& (e_{1}^{j},e_{2}^{j},e_{3}^{j}) \\
#  &  & e_i^j \sim f, f(z;\zeta) =  1/\zeta \exp(-z/\zeta)
# \end{eqnarray*}
# $$

# %% [markdown]
# Let $p_3 = 1$ be the **numeraire**. The implied **demand functions** are:
#
# $$
# \begin{eqnarray*}
# x_{i}^{\star j}(p_{1},p_{2},\boldsymbol{e}^{j})&=&\beta^{j}_i\frac{I^j}{p_{i}} \\
# \end{eqnarray*}
# $$
#
# where consumer $j$'s income is
#
# $$I^j = p_1 e_1^j + p_2 e_2^j +p_3 e_3^j$$

# %% [markdown]
# The **parameters** and **random preferences and endowments** are given by:

# %%
# a. parameters
N = 50000
mu = np.array([3,2,1])
Sigma = np.array([[0.25, 0, 0], [0, 0.25, 0], [0, 0, 0.25]])
gamma = 0.8
zeta = 1

# b. random draws
seed = 1986
np.random.seed(seed)

# preferences
alphas = np.exp(np.random.multivariate_normal(mu, Sigma, size=N))
betas = alphas/np.reshape(np.sum(alphas,axis=1),(N,1))

# endowments
e1 = np.random.exponential(zeta,size=N)
e2 = np.random.exponential(zeta,size=N)
e3 = np.random.exponential(zeta,size=N)

# %% [markdown]
# ## **Answer 3**: Exchange economy

# %% [markdown]
# **Question 1:** Plot the histograms of the budget shares for each good across agents.

# %% [markdown]
# ### **Answer 3.1:**

# %% [markdown]
# We see from the demand function that the budget shares are the betas, we take a look at them below.

# %%
print(betas)
print(betas.shape)
print(type(betas))
# Out:
# [[0.53104511 0.30693723 0.16201766]
#  [0.50866997 0.4162364  0.07509363]
#  [0.83317207 0.07722226 0.08960567]
#  ...
#  [0.63725404 0.22027742 0.14246854]
#  [0.78205036 0.11988119 0.09806844]
#  [0.65552751 0.24728801 0.09718448]]
# (50000, 3)
# <class 'numpy.ndarray'>

# %% [markdown]
# We have three columns with 50.000 budget shares for each of the three goods, below we plot them as histograms.

# %%
fig = plt.figure(figsize=(12,6))
ax1 = fig.add_subplot(1,3,1)
ax2 = fig.add_subplot(1,3,2)
ax3 = fig.add_subplot(1,3,3)

font = {'family':'serif','color':'darkblue','weight':'normal','size': 16,}

ax1.hist(betas[:,0], bins=500)
ax2.hist(betas[:,1], bins=500)
ax3.hist(betas[:,2], bins=500)

fig.suptitle('Histograms of the budget shares',fontsize=20,fontdict=font)
ax1.set_ylabel('Consumers',fontdict=font)
ax1.set_title('Good 1',fontdict=font)
ax1.set_ylim(0,500)
ax1.set_xlim(0,1)
ax1.grid(linestyle='--', linewidth=1)
ax2.set_title('Good 2',fontdict=font)
ax2.set_ylim(0,500)
ax2.set_xlim(0,1)
ax2.grid(linestyle='--', linewidth=1)
ax3.set_title('Good 3',fontdict=font)
ax3.set_ylim(0,500)
ax3.set_xlim(0,1)
ax3.grid(linestyle='--', linewidth=1)

# %% [markdown]
# We now see how the 50.000 consumers distributes their income on the three goods. Each column for a value of beta represents 100 consumers.
# We see that the consumers budget share on good 1 is largest, second on good 2, and that almost all consumers use oner 20 percent of their budget on good 3.

# %% [markdown]
# Consider the **excess demand functions:**
#
# $$ z_i(p_1,p_2) = \sum_{j=1}^N x_{i}^{\star j}(p_{1},p_{2},\boldsymbol{e}^{j}) - e_i^j$$
#
# **Question 2:** Plot the excess demand functions.

# %% [markdown]
# ### **Answer 3.2:**

# %% [markdown]
# In the next couple of questions a lot of the inspiration came from Problem set 2, Problem set 7.4 (again) and lecture notebook 4.
#
# First we define the demand functions and excess demand functions for good 1 and good 2, good 3 has the numéraire price, and we do not need it for our analysis.

# %%
# demand functions
def demand_good_1_func(betas,p1,p2,e1,e2,e3):
    I = p1*e1+p2*e2+e3
    return betas[:,0]*(I/p1)

def demand_good_2_func(betas,p1,p2,e1,e2,e3):
    I = p1*e1+p2*e2+e3
    return betas[:,1]*(I/p2)

# excess demand functions
def excess_demand_good_1_func(betas,p1,p2,e1,e2,e3):
    
    # demand
    demand = np.sum(demand_good_1_func(betas,p1,p2,e1,e2,e3))
    
    # supply
    supply = np.sum(e1)
    
    # excess demand
    excess_demand = demand-supply
    
    return excess_demand

def excess_demand_good_2_func(betas,p1,p2,e1,e2,e3):
    
    # demand
    demand = np.sum(demand_good_2_func(betas,p1,p2,e1,e2,e3))
    
    # supply
    supply = np.sum(e2)
    
    # excess demand
    excess_demand = demand-supply
    
    return excess_demand

# %% [markdown]
# To plot the excess demand function for good 1 and good 2, we first define a price vector for the two goods, and set up grids for the prices and endowments.

# %%
p1_vec = np.linspace(0.1,10,100)
p2_vec = np.linspace(0.1,10,100)
e1_grid = np.empty((100,100))
e2_grid = np.empty((100,100))

p1_grid,p2_grid = np.meshgrid(p1_vec,p2_vec,indexing='ij')

for i,p1 in enumerate(p1_vec):
    for j,p2 in enumerate(p2_vec):
        e1_grid[i,j] = excess_demand_good_1_func(betas,p1,p2,e1,e2,e3)
        e2_grid[i,j] = excess_demand_good_2_func(betas,p1,p2,e1,e2,e3)

# %% [markdown]
# We can now plot the two excess demand functions for good 1 and good 2.

# %%
fig = plt.figure(figsize=(8,12))
ax = fig.add_subplot(2,1,1,projection='3d')
cs = ax.plot_surface(p1_grid,p2_grid,e1_grid,cmap=cm.jet)
font = {'family':'serif','color':'darkblue','weight':'normal','size': 16,}
ax.invert_xaxis()
ax.set_xlabel('$p_1$',fontdict=font)
ax.set_ylabel('$p_2$',fontdict=font)
ax.set_zlabel('$e_1$',fontdict=font)
ax.set_title('Excess demand for good 1',fontdict=font)
ax.xaxis.pane.fill = False
ax.yaxis.pane.fill = False
ax.zaxis.pane.fill = False

ax1 = fig.add_subplot(2,1,2,projection='3d')
cs1 = ax1.plot_surface(p1_grid,p2_grid,e2_grid,cmap=cm.jet)
ax1.invert_xaxis()
ax1.set_xlabel('$p_1$',fontdict=font)
ax1.set_ylabel('$p_2$',fontdict=font)
ax1.set_zlabel('$e_2$',fontdict=font)
ax1.set_title('Excess demand for good 2',fontdict=font)
ax1.xaxis.pane.fill = False
ax1.yaxis.pane.fill = False
ax1.zaxis.pane.fill = False

# %% [markdown]
# When the price for good 2, the excess demend increses for good 1 and and vice versa.

# %% [markdown]
# **Quesiton 3:** Find the Walras-equilibrium prices, $(p_1,p_2)$, where both excess demands are (approximately) zero, e.g. by using the following tâtonnement process:
#
# 1. Guess on $p_1 > 0$, $p_2 > 0$ and choose tolerance $\epsilon > 0$ and adjustment aggressivity parameter, $\kappa > 0$.
# 2. Calculate $z_1(p_1,p_2)$ and $z_2(p_1,p_2)$.
# 3. If $|z_1| < \epsilon$ and $|z_2| < \epsilon$ then stop.
# 4. Else set $p_1 = p_1 + \kappa \frac{z_1}{N}$ and $p_2 = p_2 + \kappa \frac{z_2}{N}$ and return to step 2.

# %% [markdown]
# ### **Answer 3.3:**

# %% [markdown]
# To find the Walras-equilibrium prices we define a function that does this. We do this by constructing a while loop, define the excess demand functions for good 1 and good 2. The loop will continue as long as the absolute value of the two excess demand function is approximately larger than zero. If the excess demand functions is not zero we update the prices with an adjustment factor ($\kappa$) times the excess demand function over the number of consumers.
#
# We set up a positive initial guess on the prices and run our function for finding the Walras-equilibrium prices.

# %%
# equilibrium function
def find_equilibrium(betas,p1,p2,p3,e1,e2,e3,kappa=0.5,eps=1e-8,maxiter=50000):
    
    t = 0
    while True:
        
        # excess demand
        Z1 = excess_demand_good_1_func(betas,p1,p2,e1,e2,e3)
        Z2 = excess_demand_good_2_func(betas,p1,p2,e1,e2,e3)
        
        # stop?
        if (np.abs(Z1) < eps or np.abs(Z2) < eps) or t >= maxiter:
            print(f'{t:3d}: p1 = {p1:12.8f} -> excess demand -> {Z1:14.8f}')
            print(f'{t:3d}: p2 = {p2:12.8f} -> excess demand -> {Z2:14.8f}')
            break
        
        # updata p1 and p2
        p1 = p1 + kappa*Z1/betas.size
        p2 = p2 + kappa*Z2/betas.size
        
        # return
        if t < 5 or t%2500 == 0:
            print(f'{t:3d}: p1 = {p1:12.8f} -> excess demand -> {Z1:14.8f}')
            print(f'{t:3d}: p2 = {p2:12.8f} -> excess demand -> {Z2:14.8f}')
        elif t == 5:
            print ('    ...')
        
        t += 1
    
    return p1, p2

# find equilibrium function
p1 = 0.1
p2 = 0.1
p3 = 1
kappa = 0.1
eps = 1e-8
p1,p2 = find_equilibrium(betas,p1,p2,p3,e1,e2,e3,kappa=kappa,eps=eps)
# Out:
#   0: p1 =   0.32412068 -> excess demand -> 336181.01951616
#   0: p2 =   0.17062307 -> excess demand -> 105934.60974196
#   1: p1 =   0.38968380 -> excess demand -> 98344.68155945
#   1: p2 =   0.21310536 -> excess demand -> 63723.43338847
#   2: p1 =   0.44453616 -> excess demand -> 82278.53723833
#   2: p2 =   0.24485666 -> excess demand -> 47626.95183257
#   3: p1 =   0.49267334 -> excess demand -> 72205.76540281
#   3: p2 =   0.27122412 -> excess demand -> 39551.17863329
#   4: p1 =   0.53608465 -> excess demand -> 65116.97854305
#   4: p2 =   0.29416045 -> excess demand -> 34404.50204615
#     ...
# 2500: p1 =   5.91729586 -> excess demand ->   573.36340186
# 2500: p2 =   2.40292169 -> excess demand ->   214.10778661
# 5000: p1 =   6.37344285 -> excess demand ->   108.45255202
# 5000: p2 =   2.57318704 -> excess demand ->    40.46628469
# 7500: p1 =   6.46495394 -> excess demand ->    23.01716914
# 7500: p2 =   2.60732963 -> excess demand ->     8.58705454
# 10000: p1 =   6.48459241 -> excess demand ->     4.99415208
# 10000: p2 =   2.61465608 -> excess demand ->     1.86312189
# 12500: p1 =   6.48886351 -> excess demand ->     1.08871213
# 12500: p2 =   2.61624945 -> excess demand ->     0.40615312
# 15000: p1 =   6.48979507 -> excess demand ->     0.23757870
# 15000: p2 =   2.61659698 -> excess demand ->     0.08863059
# 17500: p1 =   6.48999838 -> excess demand ->     0.05185594
# 17500: p2 =   2.61667282 -> excess demand ->     0.01934526
# 20000: p1 =   6.49004275 -> excess demand ->     0.01131907
# 20000: p2 =   2.61668938 -> excess demand ->     0.00422267
# 22500: p1 =   6.49005244 -> excess demand ->     0.00247074
# 22500: p2 =   2.61669299 -> excess demand ->     0.00092173
# 25000: p1 =   6.49005456 -> excess demand ->     0.00053932
# 25000: p2 =   2.61669378 -> excess demand ->     0.00020120
# 27500: p1 =   6.49005502 -> excess demand ->     0.00011772
# 27500: p2 =   2.61669395 -> excess demand ->     0.00004392
# 30000: p1 =   6.49005512 -> excess demand ->     0.00002570
# 30000: p2 =   2.61669399 -> excess demand ->     0.00000959
# 32500: p1 =   6.49005514 -> excess demand ->     0.00000561
# 32500: p2 =   2.61669400 -> excess demand ->     0.00000209
# 35000: p1 =   6.49005514 -> excess demand ->     0.00000122
# 35000: p2 =   2.61669400 -> excess demand ->     0.00000046
# 37500: p1 =   6.49005515 -> excess demand ->     0.00000027
# 37500: p2 =   2.61669400 -> excess demand ->     0.00000010
# 40000: p1 =   6.49005515 -> excess demand ->     0.00000006
# 40000: p2 =   2.61669400 -> excess demand ->     0.00000002
# 41287: p1 =   6.49005515 -> excess demand ->     0.00000003
# 41287: p2 =   2.61669400 -> excess demand ->     0.00000001

# %%
Z1 = excess_demand_good_1_func(betas,p1,p2,e1,e2,e3)
Z2 = excess_demand_good_2_func(betas,p1,p2,e1,e2,e3)
assert(np.abs(Z1) < 1e-5)
assert(np.abs(Z2) < 1e-5)
print(f'Walras-equilibrium price for good 1 is p1 = {p1:.4f}')
print(f'Walras-equilibrium price for good 2 is p2 = {p2:.4f}')
# Out:
# Walras-equilibrium price for good 1 is p1 = 6.4901
# Walras-equilibrium price for good 2 is p2 = 2.6167

# %% [markdown]
# We have found the Walras-equilibrium prices, and the last most recent cell we assert that the result is correct.

# %% [markdown]
# **Question 4:** Plot the distribution of utility in the Walras-equilibrium and calculate its mean and variance.

# %% [markdown]
# ### **Answer 3.4:**

# %% [markdown]
# To plot the distribution of utility in the Walras-equilibrium we will first define the utility function below and then plot the utility for all consumers, for all tree goods, and with  the newly found Walras-equilibrium prices.

# %%
def u(p1,p2,e1,e2,e3,betas,gamma):
    
    I = p1*e1 + p2*e2 + e3
    
    x1 = betas[:,0]*(I/p1)
    x2 = betas[:,1]*(I/p2)
    x3 = betas[:,0]*I
    
    utility = ((x1**betas[:,0])*(x2**betas[:,1])*(x3**betas[:,2]))**gamma
    
    return utility

fig = plt.figure(figsize=(12,6))
ax = fig.add_subplot(1,1,1)
ax.hist(u(p1,p2,e1,e2,e3,betas,gamma),bins=500)
font = {'family':'serif','color':'darkblue','weight':'normal','size': 16,}
ax.set_xlabel('Utility',fontdict=font)
ax.set_ylabel('Consumers',fontdict=font)
ax.set_title('Distribution of utility in the Walras-equilibrium',fontdict=font)
print(f'Walras-equilibrium prices: p1 = {p1:.4f} and p2 = {p2:.4f}')
# Out:
# Walras-equilibrium prices: p1 = 6.4901 and p2 = 2.6167

# %% [markdown]
# Above the distribution of utility is plotted as a histogram, each column represent 100 consumers.
#
# Now we will calculate the mean and variance for the utility for the Walras-equilibrium prices.

# %%
mean = np.mean(u(p1,p2,e1,e2,e3,betas,gamma))
var = np.var(u(p1,p2,e1,e2,e3,betas,gamma))
print(f'The mean of the distribution of utility is     : {mean:.6f}')
print(f'The variance of the distribution of utility is : {var:.6f}')
# Out:
# The mean of the distribution of utility is     : 1.149799
# The variance of the distribution of utility is : 0.410472

# %% [markdown]
# **Question 5:** Find the Walras-equilibrium prices if instead all endowments were distributed equally. Discuss the implied changes in the distribution of utility. Does the value of $\gamma$ play a role for your conclusions?

# %% [markdown]
# ### **Answer 3.5:**

# %% [markdown]
# To find the Walras-equilibrium prices when all endowments are distributed equally we repeat the analysis from question 3.3, but with new demand function and then also new excess demand function.
#
# Then we set up a similar function to find the Walras-equilibrium prices, as in question 3.3, but with our new excess demand functions for good 1 and good 2, and in the end we assert the new result again. We compare with the old prices.
#
# We define a new $e$ and use it as the same endowment for each good.

# %%
seed = 1986
np.random.seed(seed)
e = np.random.exponential(zeta,size=N)
e
# Out:
# array([0.84135796, 0.08049262, 0.9377173 , ..., 0.93301125, 0.1662921 ,
#        0.86688618])

# %%
# demand functions
def demand_good_1_func2(betas,p1_new,p2_new,e):
    I = (p1_new+p2_new+1)*e
    return betas[:,0]*(I/p1_new)

def demand_good_2_func2(betas,p1_new,p2_new,e):
    I = (p1_new+p2_new+1)*e
    return betas[:,1]*(I/p2_new)

# excess demand functions
def excess_demand_good_1_func2(betas,p1_new,p2_new,e):
    
    # demand
    demand = np.sum(demand_good_1_func2(betas,p1_new,p2_new,e))
    
    # supply
    supply = np.sum(e)
    
    # excess demand
    excess_demand = demand-supply
    
    return excess_demand

def excess_demand_good_2_func2(betas,p1_new,p2_new,e):
    
    # demand
    demand = np.sum(demand_good_2_func2(betas,p1_new,p2_new,e))
    
    # supply
    supply = np.sum(e)
    
    # excess demand
    excess_demand = demand-supply
    
    return excess_demand

# %%
# equilibrium function
def find_equilibrium2(betas,p1_new,p2_new,p3_new,e,kappa=1/3,eps=1e-8,maxiter=50000):
    
    t = 0
    while True:
        
        # excess demand
        Z1 = excess_demand_good_1_func2(betas,p1_new,p2_new,e)
        Z2 = excess_demand_good_2_func2(betas,p1_new,p2_new,e)
        
        eps = 1e-8
        
        # stop?
        if (np.abs(Z1) < eps or np.abs(Z2) < eps) or t >= maxiter:
            print(f'{t:3d}: p1_new = {p1_new:12.8f} -> excess demand -> {Z1:14.8f}')
            print(f'{t:3d}: p2_new = {p2_new:12.8f} -> excess demand -> {Z2:14.8f}')
            break
        
        # updata p1 and p2
        p1_new = p1_new + kappa*Z1/betas.size
        p2_new = p2_new + kappa*Z2/betas.size
        
        # return
        if t < 5 or t%2500 == 0:
            print(f'{t:3d}: p1_new = {p1:12.8f} -> excess demand -> {Z1:14.8f}')
            print(f'{t:3d}: p2_new = {p2:12.8f} -> excess demand -> {Z2:14.8f}')
        elif t == 5:
            print ('    ...')
        
        t += 1
    
    return p1_new, p2_new

# find equilibrium function
p1_new = 0.1
p2_new = 0.1
p3_new = 1
kappa = 1/3
eps = 1e-8
p1_new,p2_new = find_equilibrium2(betas,p1_new,p2,p3,e,kappa=kappa,eps=eps)
# Out:
#   0: p1_new =   6.49005515 -> excess demand -> 1144717.03167400
#   0: p2_new =   2.61669400 -> excess demand -> -31699.11009568
#   1: p1_new =   6.49005515 -> excess demand -> 25198.74887610
#   1: p2_new =   2.61669400 -> excess demand -> -18629.47212514
#   2: p1_new =   6.49005515 -> excess demand -> 23811.47472471
#   2: p2_new =   2.61669400 -> excess demand -> -18034.52572804
#   3: p1_new =   6.49005515 -> excess demand -> 22541.26400707
#   3: p2_new =   2.61669400 -> excess demand -> -17446.33271088
#   4: p1_new =   6.49005515 -> excess demand -> 21373.47476083
#   4: p2_new =   2.61669400 -> excess demand -> -16864.67735461
#     ...
# 2500: p1_new =   6.49005515 -> excess demand ->    10.46744519
# 2500: p2_new =   2.61669400 -> excess demand ->     3.89646489
# 5000: p1_new =   6.49005515 -> excess demand ->     0.06116827
# 5000: p2_new =   2.61669400 -> excess demand ->     0.02276926
# 7500: p1_new =   6.49005515 -> excess demand ->     0.00035868
# 7500: p2_new =   2.61669400 -> excess demand ->     0.00013351
# 10000: p1_new =   6.49005515 -> excess demand ->     0.00000210
# 10000: p2_new =   2.61669400 -> excess demand ->     0.00000078
# 12122: p1_new =   6.44364203 -> excess demand ->     0.00000003
# 12122: p2_new =   2.59209951 -> excess demand ->     0.00000001

# %%
assert(np.abs(Z1) < 1e-5)
assert(np.abs(Z2) < 1e-5)
print(f'Walras-equilibrium price for good 1 is                     :  p1      =  {p1:.4f}')
print(f'Walras-equilibrium price for good 1 with equal edowment is :  p1_new  =  {p1_new:.4f}')
print(f'Walras-equilibrium price for good 2 is                     :  p2      =  {p2:.4f}')
print(f'Walras-equilibrium price for good 2 with equal edowment is :  p2_new  =  {p2_new:.4f}')
# Out:
# Walras-equilibrium price for good 1 is                     :  p1      =  6.4901
# Walras-equilibrium price for good 1 with equal edowment is :  p1_new  =  6.4436
# Walras-equilibrium price for good 2 is                     :  p2      =  2.6167
# Walras-equilibrium price for good 2 with equal edowment is :  p2_new  =  2.5921

# %% [markdown]
# We have found the new Walras-equilibrium prices where the endowments are equal, both the price for each good decreases slightly.

# %% [markdown]
# We will now repeat the analysis from question 3.4, and find and plot distribution of the new utility where the endowments are equal.
# We also calculate the mean and variance of the new utility and compared it with the old.

# %%
def u_new(p1_new,p2_new,e,betas,gamma):
    
    I = (p1 + p2 + 1)*e
    
    x1 = betas[:,0]*(I/p1)
    x2 = betas[:,1]*(I/p2)
    x3 = betas[:,0]*I
    
    utility_new = ((x1**betas[:,0])*(x2**betas[:,1])*(x3**betas[:,2]))**gamma
    
    return utility_new

fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(2,1,1)
ax.hist(u_new(p1_new,p2_new,e,betas,gamma),bins=500)
font = {'family':'serif','color':'darkblue','weight':'normal','size': 20,}
ax.set_xlabel('Utility',fontdict=font)
ax.set_xlim(-0.1,8)
ax.set_ylim(0,600)
ax.set_ylabel('Consumers',fontdict=font)
ax.set_title('Distribution of utility in the Walras-equilibrium with equal endowments',fontdict=font)
ax1 = fig.add_subplot(2,1,2)
ax1.hist(u(p1,p2,e1,e2,e3,betas,gamma),bins=500)
ax1.set_xlabel('Utility',fontdict=font)
ax1.set_xlim(-0.1,8)
ax1.set_ylim(0,600)
ax1.set_ylabel('Consumers',fontdict=font)
ax1.set_title('Distribution of utility in the Walras-equilibrium',fontdict=font)
plt.tight_layout()
mean_new = np.mean(u_new(p1_new,p2_new,e,betas,gamma))
var_new = np.var(u_new(p1_new,p2_new,e,betas,gamma))
print(f'The mean of the distribution of the new utility is     : {mean_new:.4f}')
print(f'The mean of the distribution of the old utility is     : {mean:.4f}')
print(f'The variance of the distribution of the new utility is : {var_new:.4f}')
print(f'The variance of the distribution of the old utility is : {var:.4f}')
print(u_new(p1_new,p2_new,e,betas,gamma).size)
print(u(p1,p2,e1,e2,e3,betas,gamma).size)
# Out:
# The mean of the distribution of the new utility is     : 1.1114
# The mean of the distribution of the old utility is     : 1.1498
# The variance of the distribution of the new utility is : 0.8184
# The variance of the distribution of the old utility is : 0.4105
# 50000
# 50000

# %% [markdown]
# The mean decreases slightly, but the variance almost doubles for the new utility.
# With equal endowments we see that the utility seems smaller for many consumers.

# %%
def plot(gamma):
    fig = plt.figure(figsize=(19,8))
    ax = fig.add_subplot(2,1,1)
    ax.hist(u_new(p1_new,p2_new,e,betas,gamma),bins=500)
    font = {'family':'serif','color':'darkblue','weight':'normal','size': 16,}
    ax.set_xlabel('Utility',fontdict=font)
    ax.set_ylabel('Consumers',fontdict=font)
    ax.set_title('Distribution of utility in the Walras-equilibrium with equal endowments',fontdict=font)
    ax1 = fig.add_subplot(2,1,2)
    ax1.hist(u(p1,p2,e1,e2,e3,betas,gamma),bins=500)
    ax1.set_xlabel('Utility',fontdict=font)
    ax1.set_ylabel('Consumers',fontdict=font)
    ax1.set_title('Distribution of utility in the Walras-equilibrium',fontdict=font)
    plt.tight_layout()
    return ax,ax1

widgets.interact(
        plot, 
        gamma = widgets.FloatSlider(
            description="$\\gamma$",
            min=-1,
            max=2,
            step=0.01,
            value=0.8,
            continuous_update=False,
        ),
)
# Out:
# interactive(children=(FloatSlider(value=0.8, continuous_update=False, description='$\\gamma$', max=2.0, min=-1…
# <function __main__.plot(gamma)>

# %%
print(f'The mean of the distribution of the new utility is with gamma = -1       : {np.mean(u_new(p1_new,p2_new,e,betas,-1)):.4f}')
print(f'The mean of the distribution of the old utility is with gamma = -1       : {np.mean(u(p1,p2,e1,e2,e3,betas,-1)):.4f}')
print(f'The variance of the distribution of the new utility is with gamma = -1   : {np.var(u_new(p1_new,p2_new,e,betas,-1)):.4f}')
print(f'The variance of the distribution of the old utility is with gamma = -1   : {np.var(u(p1,p2,e1,e2,e3,betas,-1)):.4f}')
print(f'The mean of the distribution of the new utility is with gamma = -0.5     : {np.mean(u_new(p1_new,p2_new,e,betas,-0.5)):.4f}')
print(f'The mean of the distribution of the old utility is with gamma = -0.5     : {np.mean(u(p1,p2,e1,e2,e3,betas,-0.5)):.4f}')
print(f'The variance of the distribution of the new utility is with gamma = -0.5 : {np.var(u_new(p1_new,p2_new,e,betas,-0.5)):.4f}')
print(f'The variance of the distribution of the old utility is with gamma = -0.5 : {np.var(u(p1,p2,e1,e2,e3,betas,-0.5)):.4f}')
print(f'The mean of the distribution of the new utility is with gamma = 0        : {np.mean(u_new(p1_new,p2_new,e,betas,0)):.4f}')
print(f'The mean of the distribution of the old utility is with gamma = 0        : {np.mean(u(p1,p2,e1,e2,e3,betas,0)):.4f}')
print(f'The variance of the distribution of the new utility is with gamma = 0    : {np.var(u_new(p1_new,p2_new,e,betas,0)):.4f}')
print(f'The variance of the distribution of the old utility is with gamma = 0    : {np.var(u(p1,p2,e1,e2,e3,betas,0)):.4f}')
print(f'The mean of the distribution of the new utility is with gamma = 0.5      : {np.mean(u_new(p1_new,p2_new,e,betas,0.5)):.4f}')
print(f'The mean of the distribution of the old utility is with gamma = 0.5      : {np.mean(u(p1,p2,e1,e2,e3,betas,0.5)):.4f}')
print(f'The variance of the distribution of the new utility is with gamma = 0.5  : {np.var(u_new(p1_new,p2_new,e,betas,0.5)):.4f}')
print(f'The variance of the distribution of the old utility is with gamma = 0.5  : {np.var(u(p1,p2,e1,e2,e3,betas,0.5)):.4f}')
print(f'The mean of the distribution of the new utility is with gamma = 1        : {np.mean(u_new(p1_new,p2_new,e,betas,1)):.4f}')
print(f'The mean of the distribution of the old utility is with gamma = 1        : {np.mean(u(p1,p2,e1,e2,e3,betas,1)):.4f}')
print(f'The variance of the distribution of the new utility is with gamma = 1    : {np.var(u_new(p1_new,p2_new,e,betas,1)):.4f}')
print(f'The variance of the distribution of the old utility is with gamma = 1    : {np.var(u(p1,p2,e1,e2,e3,betas,1)):.4f}')
print(f'The mean of the distribution of the new utility is with gamma = 1.5      : {np.mean(u_new(p1_new,p2_new,e,betas,1.5)):.4f}')
print(f'The mean of the distribution of the old utility is with gamma = 1.5      : {np.mean(u(p1,p2,e1,e2,e3,betas,1.5)):.4f}')
print(f'The variance of the distribution of the new utility is with gamma = 1.5  : {np.var(u_new(p1_new,p2_new,e,betas,1.5)):.4f}')
print(f'The variance of the distribution of the old utility is with gamma = 1.5  : {np.var(u(p1,p2,e1,e2,e3,betas,1.5)):.4f}')
print(f'The mean of the distribution of the new utility is with gamma = 2        : {np.mean(u_new(p1_new,p2_new,e,betas,2)):.4f}')
print(f'The mean of the distribution of the old utility is with gamma = 2        : {np.mean(u(p1,p2,e1,e2,e3,betas,2)):.4f}')
print(f'The variance of the distribution of the new utility is with gamma = 2    : {np.var(u_new(p1_new,p2_new,e,betas,2)):.4f}')
print(f'The variance of the distribution of the old utility is with gamma = 2    : {np.var(u(p1,p2,e1,e2,e3,betas,2)):.4f}')
# Out:
# The mean of the distribution of the new utility is with gamma = -1       : 18.5154
# The mean of the distribution of the old utility is with gamma = -1       : 1.3736
# The variance of the distribution of the new utility is with gamma = -1   : 2501979.7256
# The variance of the distribution of the old utility is with gamma = -1   : 2.5738
# The mean of the distribution of the new utility is with gamma = -0.5     : 1.6037
# The mean of the distribution of the old utility is with gamma = -0.5     : 1.0830
# The variance of the distribution of the new utility is with gamma = -0.5 : 15.9435
# The variance of the distribution of the old utility is with gamma = -0.5 : 0.2006
# The mean of the distribution of the new utility is with gamma = 0        : 1.0000
# The mean of the distribution of the old utility is with gamma = 0        : 1.0000
# The variance of the distribution of the new utility is with gamma = 0    : 0.0000
# The variance of the distribution of the old utility is with gamma = 0    : 0.0000
# The mean of the distribution of the new utility is with gamma = 0.5      : 0.9889
# The mean of the distribution of the old utility is with gamma = 0.5      : 1.0538
# The variance of the distribution of the new utility is with gamma = 0.5  : 0.2706
# The variance of the distribution of the old utility is with gamma = 0.5  : 0.1343
# The mean of the distribution of the new utility is with gamma = 1        : 1.2486
# The mean of the distribution of the old utility is with gamma = 1        : 1.2447
# The variance of the distribution of the new utility is with gamma = 1    : 1.6077
# The variance of the distribution of the old utility is with gamma = 1    : 0.7669
# The mean of the distribution of the new utility is with gamma = 1.5      : 1.8645
# The mean of the distribution of the old utility is with gamma = 1.5      : 1.6248
# The variance of the distribution of the new utility is with gamma = 1.5  : 8.8312
# The variance of the distribution of the old utility is with gamma = 1.5  : 3.2580
# The mean of the distribution of the new utility is with gamma = 2        : 3.1667
# The mean of the distribution of the old utility is with gamma = 2        : 2.3162
# The variance of the distribution of the new utility is with gamma = 2    : 54.9530
# The variance of the distribution of the old utility is with gamma = 2    : 13.8794

# %%
g_vec = np.linspace(0.1,2,500)
u_new_mean_vec = np.empty(500)
u_old_mean_vec = np.empty(500)
u_new_var_vec = np.empty(500)
u_old_var_vec = np.empty(500)

def dist(gamma):
    
    for i,g in enumerate(g_vec):
        
        u_new_mean_vec[i] = np.mean(u_new(p1_new,p2_new,e,betas,g_vec[i]))
        u_old_mean_vec[i] = np.mean(u(p1,p2,e1,e2,e3,betas,g_vec[i]))
        u_new_var_vec[i] = np.var(u_new(p1_new,p2_new,e,betas,g_vec[i]))
        u_old_var_vec[i] = np.var(u(p1,p2,e1,e2,e3,betas,g_vec[i]))
        
        return u_new_mean_vec, u_old_mean_vec, u_new_var_vec, u_old_var_vec
u_old_var_vec
#u_new_mean_vec, u_old_mean_vec, u_new_var_vec, u_old_var_vec = dist(gamma)
#fig = plt.figure()
#ax = fig.add_subplot(1,2,1)
#ax.plot(g_vec,u_new_mean_vec)
#ax.plot(g_vec,u_old_mean_vec)
#ax.plot(g_vec,u_new_var_vec)
#ax.plot(g_vec,u_old_var_vec)
# Out:
# array([0.00000000e+000, 3.92288123e-320, 0.00000000e+000, 6.94800570e-310,
#        1.33856822e-152, 6.94800590e-310, 3.03760123e-152, 1.45913393e-152,
#        1.27319747e-313, 6.01346930e-154, 6.94800590e-310, 6.94800590e-310,
#        6.94800590e-310, 3.95252517e-323, 1.45174486e-094, 6.94800570e-310,
#        7.35874515e+223, 1.27731747e-152, 1.33856861e-152, 8.89486967e+252,
#        3.95252517e-323, 1.27734646e-152, 2.21473185e-314, 6.63061426e+265,
#        1.29642008e+219, 4.44659081e-323, 4.94065646e-324, 6.94800570e-310,
#        0.00000000e+000, 0.00000000e+000, 4.36459812e-091, 2.22221194e-314,
#        6.96770688e+252, 1.00838745e+261, 1.48539705e-313, 2.02762924e+174,
#        6.94800570e-310, 2.22067909e-314, 1.54527077e+256, 1.48539705e-313,
#        4.94065646e-324, 6.94800570e-310, 0.00000000e+000, 0.00000000e+000,
#        4.51019739e+223, 4.05905887e-313, 2.86749892e+161, 5.26031821e-086,
#        3.18299369e-313, 2.47032823e-323, 6.94800570e-310, 6.94800570e-310,
#        6.94800570e-310, 6.94800570e-310, 6.94800570e-310, 0.00000000e+000,
#        0.00000000e+000, 1.03983855e-152, 4.05882413e-313, 9.31475709e+242,
#        9.59801861e-066, 4.45619116e-313, 1.45174486e-094, 4.05891407e-313,
#        7.35874497e+223, 1.27731747e-152, 5.94158822e-313, 8.89486879e+252,
#        2.21514795e-314, 1.27734646e-152, 1.71387261e+214, 7.42698527e-313,
#        1.29642000e+219, 4.05725586e-313, 1.20649494e+285, 6.16830600e-114,
#        7.85138443e-313, 3.77220857e+150, 2.21411297e-314, 1.57589701e-052,
#        1.82161976e-118, 9.12458190e-313, 3.77690737e+180, 6.94800570e-310,
#        6.94800570e-310, 6.94800570e-310, 3.18299369e-313, 5.82480416e+252,
#        6.94800570e-310, 6.94800570e-310, 6.94800570e-310, 1.48539705e-313,
#        8.59161470e-114, 6.94800570e-310, 8.11985841e+164, 4.05995601e-313,
#        1.13447167e+296, 6.96770841e+252, 1.27319748e-313, 4.94065646e-324,
#        6.94800570e-310, 9.79881915e+252, 6.94800570e-310, 1.54527139e+256,
#        2.46296151e+198, 1.27319748e-313, 2.49117617e-091, 6.94800570e-310,
#        6.92584141e+151, 6.94800570e-310, 1.27319748e-313, 2.86749892e+161,
#        4.06012482e-313, 1.02250455e-259, 6.86471957e-119, 1.27319748e-313,
#        9.88131292e-324, 6.94800570e-310, 6.94800570e-310, 1.27734646e-152,
#        6.94800570e-310, 6.63061504e+265, 1.29642008e+219, 1.27319748e-313,
#        1.87205750e+261, 6.94800570e-310, 6.94800570e-310, 6.94800570e-310,
#        4.44659081e-323, 1.02250430e-259, 6.94800570e-310, 5.03061519e+223,
#        1.27734658e-152, 2.76455339e+257, 1.33856861e-152, 4.44659081e-323,
#        3.03760046e-152, 2.21473185e-314, 2.17235213e-153, 6.01347002e-154,
#        4.94065646e-323, 4.94065646e-324, 6.94800570e-310, 0.00000000e+000,
#        0.00000000e+000, 1.13447149e+296, 2.22221194e-314, 4.52176431e+217,
#        2.34840919e+251, 1.48539705e-313, 1.81596849e-152, 6.94800570e-310,
#        2.22067909e-314, 1.10639915e+200, 1.48539705e-313, 4.94065646e-324,
#        6.94800570e-310, 0.00000000e+000, 0.00000000e+000, 9.08020616e-096,
#        2.21496180e-314, 1.95349190e-110, 1.29888786e+184, 3.18299369e-313,
#        3.45845952e-323, 6.94800570e-310, 6.94800570e-310, 6.94800570e-310,
#        6.94800570e-310, 6.94800570e-310, 6.94800570e-310, 6.94800570e-310,
#        0.00000000e+000, 0.00000000e+000, 1.38207428e+267, 2.22034255e-314,
#        1.45174486e-094, 1.13447167e+296, 3.60739285e-313, 1.00838714e+261,
#        2.22358179e-314, 2.02762924e+174, 9.79882228e+252, 4.24399158e-313,
#        1.53831581e+256, 2.21648397e-314, 5.71141182e+188, 7.01204005e-077,
#        4.88059032e-313, 8.59163948e-114, 2.21648400e-314, 8.11985841e+164,
#        2.09473147e-110, 5.51718906e-313, 6.86471753e-119, 4.05602907e-313,
#        1.27734646e-152, 2.76455339e+257, 6.15378779e-313, 2.79195046e-152,
#        4.05725586e-313, 1.45913350e-152, 2.17235262e-153, 6.79038653e-313,
#        8.39459618e+217, 2.21411297e-314, 1.38207447e+267, 1.75253613e-094,
#        8.06358401e-313, 2.40773444e-057, 6.94800570e-310, 6.94800570e-310,
#        6.94800570e-310, 3.18299369e-313, 4.82412216e+228, 6.94800570e-310,
#        6.94800570e-310, 6.94800570e-310, 1.48539705e-313, 1.57588652e-052,
#        6.94800570e-310, 5.03061463e+223, 4.05995599e-313, 2.28522059e+179,
#        1.45174531e-094, 1.27319748e-313, 4.94065646e-324, 6.94800570e-310,
#        9.17239178e+170, 6.94800570e-310, 1.17231884e+166, 2.64521041e+185,
#        1.27319748e-313, 1.13072611e+277, 6.94800570e-310, 2.90977637e-014,
#        6.94800570e-310, 1.27319748e-313, 1.46322258e-070, 4.06012483e-313,
#        2.35659013e+180, 3.52286675e-110, 1.27319748e-313, 9.88131292e-324,
#        6.94800570e-310, 6.94800570e-310, 8.87663151e+247, 6.94800570e-310,
#        3.17095857e+180, 9.78701468e+199, 1.27319748e-313, 7.67903759e+218,
#        6.94800570e-310, 6.94800570e-310, 6.94800570e-310, 4.94065646e-323,
#        4.89919632e+252, 6.94800570e-310, 1.02250455e-259, 6.86471957e-119,
#        5.03061519e+223, 1.27734658e-152, 4.94065646e-323, 1.33856822e-152,
#        2.21473185e-314, 3.03760046e-152, 1.45913393e-152, 5.43472210e-323,
#        4.94065646e-324, 6.94800570e-310, 0.00000000e+000, 0.00000000e+000,
#        1.75253571e-094, 2.22221194e-314, 1.13447149e+296, 6.96770841e+252,
#        1.48539705e-313, 2.34840891e+251, 6.94800570e-310, 2.21536434e-314,
#        1.94208298e+227, 1.48539705e-313, 4.94065646e-324, 6.94800570e-310,
#        0.00000000e+000, 0.00000000e+000, 2.29271752e+256, 4.05905887e-313,
#        9.08020616e-096, 2.85643166e-110, 2.97079411e-313, 2.47032823e-323,
#        6.94800570e-310, 6.94800570e-310, 6.94800570e-310, 6.94800570e-310,
#        6.94800570e-310, 0.00000000e+000, 0.00000000e+000, 7.67903759e+218,
#        4.05882413e-313, 5.28640148e-085, 3.93852326e+180, 4.24399158e-313,
#        1.75253571e-094, 4.05891407e-313, 1.13447149e+296, 6.96770841e+252,
#        5.72938864e-313, 1.27617563e-152, 2.21514795e-314, 9.79881915e+252,
#        2.34840919e+251, 7.21478569e-313, 2.46296057e+198, 4.05725586e-313,
#        4.59540892e-072, 1.56884753e+224, 7.63918485e-313, 9.58663072e-071,
#        2.21411297e-314, 2.09505633e-110, 1.02250455e-259, 8.91238232e-313,
#        5.03061463e+223, 6.94800570e-310, 6.94800570e-310, 6.94800570e-310,
#        2.97079411e-313, 3.03760046e-152, 6.94800570e-310, 6.94800570e-310,
#        6.94800570e-310, 1.48539705e-313, 3.93852295e+180, 6.94800570e-310,
#        1.75253571e-094, 4.05995598e-313, 2.40773464e-057, 8.82069537e+199,
#        1.27319748e-313, 4.94065646e-324, 6.94800570e-310, 4.82412216e+228,
#        6.94800570e-310, 9.78701468e+199, 2.31634008e-152, 1.27319748e-313,
#        1.57609043e-052, 6.94800570e-310, 5.03061904e+223, 6.94800570e-310,
#        1.27319748e-313, 1.45174486e-094, 4.06012484e-313, 8.82069537e+199,
#        3.15476338e+180, 1.27319748e-313, 9.88131292e-324, 6.94800570e-310,
#        6.94800570e-310, 1.38201229e+267, 6.94800570e-310, 1.49005471e+195,
#        2.90977482e-014, 1.27319748e-313, 7.46386636e-114, 6.94800570e-310,
#        6.94800570e-310, 6.94800570e-310, 5.43472210e-323, 1.95349190e-110,
#        6.94800570e-310, 9.31464635e+242, 2.64519868e+185, 8.87663363e+247,
#        4.82412327e+228, 5.43472210e-323, 9.78701182e+199, 2.21473185e-314,
#        7.67903759e+218, 1.57609062e-052, 5.92878775e-323, 4.94065646e-324,
#        6.94800570e-310, 0.00000000e+000, 0.00000000e+000, 1.02250430e-259,
#        2.22221194e-314, 5.03061463e+223, 1.27734658e-152, 1.48539705e-313,
#        1.33856822e-152, 6.94800570e-310, 2.21536434e-314, 1.45913350e-152,
#        1.48539705e-313, 4.94065646e-324, 6.94800570e-310, 0.00000000e+000,
#        0.00000000e+000, 1.75253571e-094, 2.21496180e-314, 1.13447149e+296,
#        6.96770841e+252, 2.97079411e-313, 3.45845952e-323, 6.94800570e-310,
#        6.94800570e-310, 6.94800570e-310, 6.94800570e-310, 6.94800570e-310,
#        6.94800570e-310, 6.94800570e-310, 0.00000000e+000, 0.00000000e+000,
#        2.28523398e+179, 2.22034255e-314, 3.02275725e-110, 1.95349216e-110,
#        3.39519327e-313, 9.31464313e+242, 2.22358179e-314, 8.87663151e+247,
#        4.82412327e+228, 4.03179200e-313, 9.78701182e+199, 2.21648397e-314,
#        7.67903759e+218, 6.03969139e-154, 4.66839074e-313, 3.93852295e+180,
#        2.21648400e-314, 1.75253571e-094, 1.45174531e-094, 5.30498948e-313,
#        6.96770688e+252, 4.05602907e-313, 1.27617563e-152, 2.02763010e+174,
#        5.94158822e-313, 2.34840891e+251, 4.05725586e-313, 2.46296057e+198,
#        5.71141401e+188, 6.57818695e-313, 1.56884742e+224, 2.21411297e-314,
#        9.58663375e-071, 8.11985917e+164, 7.85138443e-313, 1.02250430e-259,
#        6.94800570e-310, 6.94800570e-310, 6.94800570e-310, 2.97079411e-313,
#        2.12199580e-314, 6.94800570e-310, 6.94800570e-310, 6.94800570e-310,
#        1.48539705e-313, 2.12199579e-314, 6.94800570e-310, 2.12199580e-314,
#        4.05995605e-313, 2.22560266e-314, 2.22560272e-314, 1.27319748e-313,
#        4.94065646e-324, 6.94800570e-310, 2.12199580e-314, 6.94800570e-310,
#        2.22401586e-314, 2.22402424e-314, 1.27319748e-313, 2.12199580e-314,
#        6.94800570e-310, 4.24399158e-314, 6.94800570e-310, 1.27319748e-313,
#        2.12199580e-314, 4.06065816e-313, 2.22566815e-314, 2.22566261e-314,
#        1.27319748e-313, 9.88131292e-324, 6.94800570e-310, 6.94800570e-310,
#        2.12199580e-314, 6.94800570e-310, 2.22609796e-314, 2.22610758e-314,
#        1.27319748e-313, 2.12199580e-314, 6.94800570e-310, 6.94800570e-310,
#        6.94800570e-310, 5.92878775e-323, 2.12199580e-314, 6.94800570e-310])
